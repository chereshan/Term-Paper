# %% [markdown]
# # Моделирование предпочтений

# %% [markdown]
# Ссылка на данные RLMS-HSE
#
# Согласно Условиям доступа к  данным RLMS-HSE, при использовании информации, полученной на основании RLMS-HSE, в публичных целях ссылка на источник должна быть следующей:
#
# «Российский мониторинг экономического положения и здоровья населения НИУ ВШЭ (RLMS HSE)», проводимый Национальным исследовательским университетом  "Высшая школа экономики" и ООО «Демоскоп» при участии Центра народонаселения Университета Северной Каролины в Чапел Хилле и Института социологии Федерального научно-исследовательского социологического центра РАН. (Сайты обследования RLMS HSE: http://www.hse.ru/rlms и https://rlms-hse.cpc.unc.edu)».

# %% [markdown]
# Для оценивания системы спроса на продовольственные товары
# использована выборка RLMS, содержащая данные по социальноэкономическим характеристикам домохозяйств РФ. Данные RLMS
# представлены в виде панели домохозяйств, расположенных в различных регионах РФ. При этом статистика собирается не по каждому отдельному человеку, а по всему домохозяйству, которое может
# состоять из нескольких человек. Данные RLMS основаны на соцопросах, проводимых ежегодно среди выбранных домохозяйств. При
# этом домохозяйство предоставляет данные по расходам и доходам
# только за последний месяц. Таким образом, панель RLMS представляет месячные данные по расходам и доходам домохозяйств, отличающиеся субъективностью оценки, на каждый год рассматриваемого периода

# %% [markdown]
# ## Загрузка библиотек

# %%
import pandas as pd
import pyreadstat #Для чтения файлов SPSS

# %% [markdown]
# ## Чтение данных

# %%
#Данные по домохозяйствам
df_HH=pd.read_spss(r'C:\Users\79618\Desktop\Репрезентативная выборка 10.10.2021\29-я волна\ДОМОХОЗЯЙСТВА\r29h_os41.sav')
#Данные по индивидам
df_IND=pd.read_spss(r'C:\Users\79618\Desktop\Репрезентативная выборка 10.10.2021\29-я волна\ИНДИВИДЫ\r29i_os_42.sav')

# %%
df_HH.head()
# Out:
#    YREDID_H    YID_H    XID_H    WID_H    VID_H    UID_H    TID_H    SID_H  \
# 0    1017.0  10003.0  10003.0  10003.0  10003.0  10003.0  10003.0  10003.0
# 1    1018.0  10004.0  10004.0      NaN  10004.0  10004.0  10004.0  10004.0
# 2    1020.0  10012.0  10012.0  10012.0  10012.0  10012.0  10012.0  10012.0
# 3    1022.0  10014.0  10014.0  10014.0  10014.0  10014.0  10014.0  10014.0
# 4    1023.0  10016.0  10016.0  10016.0  10016.0  10016.0  10016.0  10016.0
#
#      RID_H    QID_H  ...  yf14.12  yf14.13  yf14.14  yf14.15      yf14  \
# 0  10003.0  10003.0  ...      Нет      NaN      Нет      NaN   17376.0
# 1  10004.0  10004.0  ...      Нет      NaN      Нет      NaN   37500.0
# 2  10012.0  10012.0  ...      Нет      NaN      Нет      NaN   19700.0
# 3  10014.0  10014.0  ...      Нет      NaN      Нет      NaN   15985.0
# 4  10016.0  10016.0  ...      Нет      NaN      Нет      NaN  126000.0
#
#           yf16.1         yf16.2         yf16.3        yf16.4         yf16.5
# ...

# %%
df_IND.head()
# Out:
#    idind      yid_i  yredid_i    yid_h      xid_i    xid_h      wid_i  \
# 0    3.0  1001201.0  102001.0  10012.0  1001201.0  10012.0  1001201.0
# 1    7.0  1000301.0  101701.0  10003.0  1000301.0  10003.0  1000301.0
# 2    9.0  1000401.0  101801.0  10004.0  1000401.0  10004.0        NaN
# 3   36.0  1002401.0  102601.0  10024.0  1002401.0  10024.0  1002401.0
# 4   60.0  1004702.0  104002.0  10047.0  1004702.0  10047.0  1004702.0
#
#      wid_h      vid_i    vid_h  ...  ym109  ym111  ys1.1  ys1.2  ys2  ys3  \
# 0  10012.0  1001201.0  10012.0  ...    NaN    NaN    NaN    NaN  NaN  NaN
# 1  10003.0  1000301.0  10003.0  ...    NaN    NaN    NaN    NaN  NaN  NaN
# 2      NaN  1000401.0  10004.0  ...    NaN    NaN    NaN    NaN  NaN  NaN
# 3  10024.0        NaN      NaN  ...    NaN    NaN    NaN    NaN  NaN  NaN
# 4  10047.0  1004702.0  10047.0  ...    NaN    NaN    NaN    NaN  NaN  NaN
#
#    ys4  ys5  ys6  ys7
# 0  NaN  NaN  NaN  NaN
# 1  NaN  NaN  NaN  NaN
# 2  NaN  NaN  NaN  NaN
# ...

# %%
Агрегация индивидов в домохозяйства

# %%
Семейная анкета:
A - общая информация
B - родственные связи между членами
C - условия жизни, бытовые условия, обеспеченность товарами длительного пользования (ТДП)
D - сельскохозяйственная деятельность (подсобное хозяйство)
E - доходы
F - расходы
H - детальные расходы на образование (с 2010г.)

Индивидуальная анкета:
I - миграция и национальность
J - занятость
L - пользование медицинскими услугами
M - здоровье
N - фертильность
O - бюджет времени (1994-1998)

Детская анкета:
K - образование и двигательная активность детей
L - пользование медицинскими услугами
M - здоровье
O - бюджет времени (1994-1998)

# %%
Периоды времени:
30 дней - доходы, большинство расходов, мед. услуги, недомогания, работа, потребление алкоголя и т.п.
7 дней - покупки продуктов питания
3 месяца - расходы на ТДП
12 месяца - агропроизводство

# %% [markdown]
# ## Описание данных

# %% [markdown]
# **Коды столбцов**

# %%
for col in df_HH.columns:
    print(col)
# Out:
# YREDID_H
# YID_H
# XID_H
# WID_H
# VID_H
# UID_H
# TID_H
# SID_H
# RID_H
# QID_H
# PID_H
# OID_H
# NID_H
# MID_H
# LID_H
# KID_H
# JID_H
# IID_H
# HID_H
# GID_H
# FID_H
# EID_H
# DID_H
# CID_H
# BID_H
# AID_H
# y_origsm
# y_hhwgt
# region
# psu
# status
# popul
# site
# ya3
# ya3.3
# Y_ROUND
# YA4.1
# YA4.2
# YA5.1
# YA5.2
# YA8
# YB1.O
# YB1.N
# y_nfm
# YB1.1
# yidind1
# YB1.2.1
# YB1.2.23
# YB1.3
# YB1.4
# YB1.5
# YB2.1
# yidind2
# YB2.2.1
# YB2.2.23
# YB2.3
# YB2.4
# YB2.5
# YB2.9.1
# YB3.1
# yidind3
# YB3.2.1
# YB3.2.23
# YB3.3
# YB3.4
# YB3.5
# YB3.9.1
# YB3.9.2
# YB4.1
# yidind4
# YB4.2.1
# YB4.2.23
# YB4.3
# YB4.4
# YB4.5
# YB4.9.1
# YB4.9.2
# YB4.9.3
# YB5.1
# yidind5
# YB5.2.1
# YB5.2.23
# YB5.3
# YB5.4
# YB5.5
# YB5.9.1
# YB5.9.2
# YB5.9.3
# YB5.9.4
# YB6.1
# yidind6
# YB6.2.1
# YB6.2.23
# YB6.3
# YB6.4
# YB6.5
# YB6.9.1
# YB6.9.2
# YB6.9.3
# YB6.9.4
# YB6.9.5
# YB7.1
# yidind7
# YB7.2.1
# YB7.2.23
# YB7.3
# YB7.4
# YB7.5
# YB7.9.1
# YB7.9.2
# YB7.9.3
# YB7.9.4
# YB7.9.5
# ...

# %% [markdown]
# **y** - код волны 29-ой волны (2020)
#
# **y_nfm**  - число членов семьи

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
Описательные статистики

# %%
#Весь столбец численный, т.е. не содержит ответов-строк
df.loc[:,"y_nfm"].describe()
# Out:
# count    4831.000000
# mean        2.592838
# std         1.569647
# min         1.000000
# 25%         1.000000
# 50%         2.000000
# 75%         3.000000
# max        16.000000
# Name: y_nfm, dtype: float64

# %% [markdown]
# Таким образом, среднее домохозяйство имеет 2.592838 членов

# %%
ax = df.loc[:,"y_nfm"].plot.hist()

# %%
ax=df.loc[:,"y_nfm"].plot.pie(subplots=True, figsize=(11, 6))

# %%
ax = df.loc[:,"y_nfm"].plot.bar(x='lab', y='val', rot=0)

# %% [markdown]
# **ye3** - "Вспомните, сколько примерно денег все члены Вашей семьи
# израсходовали на питание вне дома в течение последних 7
# дней?"
#
# **ye4** - "Вспомните, сколько примерно денег все члены Вашей семьи израсходовали на питание дома и вне дома в течение
# последних 30 дней?"

# %% [markdown]
# Проблема с такого рода категориями в том, что они категориальные,
#
# т.е. содержат ответы в стиле *'ЗАТРУДНЯЮСЬ ОТВЕТИТЬ'*, *'НЕТ ОТВЕТА'* и *'ОТКАЗ ОТ ОТВЕТА'*

# %%
df.loc[:,"ye4"]
# Out:
# 0       10000.0
# 1       15000.0
# 2        5000.0
# 3        6000.0
# 4       12000.0
#          ...
# 4826    30000.0
# 4827     6000.0
# 4828    20000.0
# 4829     5300.0
# 4830    15000.0
# Name: ye4, Length: 4831, dtype: category
# Categories (166, object): [0.0, 300.0, 500.0, 700.0, ..., 85000.0, 'ЗАТРУДНЯЮСЬ ОТВЕТИТЬ', 'НЕТ ОТВЕТА', 'ОТКАЗ ОТ ОТВЕТА']

# %%
df1=pd.DataFrame(df.loc[:,"ye4"], columns=["ye4"])
df1
# Out:
#           ye4
# 0     10000.0
# 1     15000.0
# 2      5000.0
# 3      6000.0
# 4     12000.0
# ...       ...
# 4826  30000.0
# 4827   6000.0
# 4828  20000.0
# 4829   5300.0
# 4830  15000.0
#
# [4831 rows x 1 columns]

# %% [markdown]
# Нужно отчистить Series от таких категориальных ответов и трансформировать оставшиеся в численные.
#
# Пути решения проблемы категориальности данных:
# 1. Удаление категориальных строк
# 2. Замена их на среднюю численных

# %%
df1=df.loc[:,"ye4"]
df1.dtypes
# Out:
# CategoricalDtype(categories=[                   0.0,                  300.0,
#                                    500.0,                  700.0,
#                                    800.0,                 1000.0,
#                                   1200.0,                 1350.0,
#                                   1500.0,                 1750.0,
#                   ...
#                                  52000.0,                55000.0,
#                                  60000.0,                65000.0,
#                                  69000.0,                70000.0,
#                                  85000.0, 'ЗАТРУДНЯЮСЬ ОТВЕТИТЬ',
#                             'НЕТ ОТВЕТА',      'ОТКАЗ ОТ ОТВЕТА'],
# , ordered=False)

# %%
df1.info
# Out:
# <bound method Series.info of 0       10000.0
# 1       15000.0
# 2        5000.0
# 3        6000.0
# 4       12000.0
#          ...
# 4826    30000.0
# 4827     6000.0
# 4828    20000.0
# 4829     5300.0
# 4830    15000.0
# Name: ye4, Length: 4831, dtype: category
# Categories (166, object): [0.0, 300.0, 500.0, 700.0, ..., 85000.0, 'ЗАТРУДНЯЮСЬ ОТВЕТИТЬ', 'НЕТ ОТВЕТА', 'ОТКАЗ ОТ ОТВЕТА']>

# %%
df1=df1[(df1!= 'ЗАТРУДНЯЮСЬ ОТВЕТИТЬ') & (df1 != 'НЕТ ОТВЕТА')& (df1 != 'ОТКАЗ ОТ ОТВЕТА')]

# %%
df1=pd.to_numeric(df1)
df1.describe()
# Out:
# count     4529.000000
# mean     14469.739236
# std       9195.799543
# min          0.000000
# 25%       8000.000000
# 50%      12000.000000
# 75%      19700.000000
# max      85000.000000
# Name: ye4, dtype: float64

# %%
ax = df1.plot.kde()

# %% [markdown]
# Что мне нужно:
# 1. Посчичать размер фактического трудового дохода
# 2. Посчитать располагаемый доход (после налогов, трансфертов и вернутых долгов)
# 3. Посчитать сколько каждое домохозяйство тратило на различные категории товаров, а именно продукты питания, оплата дома и жкх, одежда, техника, услуги. Сколько на потребление в целом.
# 4. Размер собственности

# %% [markdown]
# Я.М. Рощина Основы моделирования экономического поведения домохозяйств
# Основнык источники денежных доходов:
# 1. Доходы от трудовой и предпринимательской деятельности:
#     1) оплата труда работников по найму
#     2) доходы от самостоятельной занятости
#     3) доходы от предпринимательской деятельности
#     4) доходы от продажи продукции подсобного хозяйства
# 2. Социальные трансферты:
#     1) пенсии
#     2) пособия
#     3) стипендии
# 3. Доходы от собственности
#     1) Проценты по вкладам и ценным бумагам
#     2) Дивиденды по акциям
#     3) рента
#     4) доходы от сдачи в аренду (жилья,земли и проч)
# 4. Частные трансферты
#     1) безвозмездная денежная помощь родственников и организаций
#     2) алименты
# 5. Прочие поступления
#     1) наследство (или его продажа, если в натур. форме)
#     2) ВЫИГРЫШИ
#     3) поступления по страховкам
#     4) другие доходы

# %% [markdown]
# Основные группы расходов домохозяйств:
# 1. Выплата обязательных платежей
#     1) подоходный налог
#     2) пенсионные взносы и взносы на социальное страхование
#     3)алименты
#     4)другие обзяательные платежи
# 2. Потери и убытки
# 3. Частные трансферты(материальная помощь в пользу лиц вне ДХ) и пожертвования
# 4. Потребительские расходы
#     1) ПОКУПКА ТОВАРОВ ДЛИТЕЛЬНОГО ПОЛЬЗОВАНИЯ И НЕдвижимости
#     2) оплата услуг
#     3) покупка товаров кратковременного пользования
# 5. Отложенные средства
#     1)наличные деньги
#     2)покупка иностранной валюты
#     3)деньги размещенные на счетах в банке
#     4)покупка акций и ценных бумаг
# 6. Произвосдтвенные расходы
# 7. Страховые взносы, возврат кредитов, погашение ссуд
# 8. Прочие расходы

# %% [markdown]
# A У Вас есть
# B Сколько лет
# C За сколько можно купить сегодня
#
# C1.1 Какова сегодня приблизительно рыночная цена такого жилья,
# как Ваше?
# C9.1C За сколько можно купить сегодня такой же холодильник?
# C9.2C За сколько можно купить сегодня такую же морозильную камеру?
# C9.3C За сколько можно купить сегодня такую же стиральную
# машину?
# C9.5C За сколько можно купить сегодня такой же цветной
# телевизор?
# C9.6C За сколько можно купить сегодня такой же видеомагнитофон?
# C9.7.0C За сколько можно купить сегодня такой же легковой или
# грузовой автомобиль?
# C9.8C За сколько можно купить сегодня такой же мотоцикл,
# мотороллер, моторную лодку?
# C9.9C За сколько можно купить сегодня такой же трактор или
# минитрактор?
# C9.10C За сколько можно купить сегодня такой же садовый домик?
# C9.11C За сколько можно купить сегодня такую же дачу или другой
# дом?
# C9.101C Сколько должны платить в месяц за дачу или другой дом,
# часть дома, садовый домик?
# C9.12C_price За сколько можно купить сегодня такую же квартиру или
# часть квартиры?
# C9.12C Сколько должны платить в месяц за другую квартиру или
# часть квартиры?
#
# D1 В течение последних 12 месяцев у Вашей семьи была в
# пользовании какая-либо земля?
# D2 В настоящее время у Вашей семьи есть в пользовании какаялибо земля?
# D3 Сколько всего соток земли у Вашей семьи в настоящее
# время?
# D6 Сколько всего рублей Вы заплатили за пользование Вашей
# землей в последние 12 месяцев?

# %%
df2 = df1.loc[df1 !='ЗАТРУДНЯЮСЬ ОТВЕТИТЬ' ]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [104], in <cell line: 1>()
# ----> 1 df2 = df1.loc[df1 !='ЗАТРУДНЯЮСЬ ОТВЕТИТЬ' ]
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:967, in _LocationIndexer.__getitem__(self, key)
#     964 axis = self.axis or 0
#     966 maybe_callable = com.apply_if_callable(key, self.obj)
# --> 967 return self._getitem_axis(maybe_callable, axis=axis)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:1189, in _LocIndexer._getitem_axis(self, key, axis)
#    1186 if not (isinstance(key, tuple) and isinstance(labels, MultiIndex)):
#    1188     if hasattr(key, "ndim") and key.ndim > 1:
# -> 1189         raise ValueError("Cannot index with multidimensional key")
#    1191     return self._getitem_iterable(key, axis=axis)
#    1193 # nested tuple slicing
#
# ...

# %%
df2 = df1[df1.isin('ЗАТРУДНЯЮСЬ ОТВЕТИТЬ','НЕТ ОТВЕТА') == False]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [86], in <cell line: 1>()
# ----> 1 df2 = df1[df1.isin('ЗАТРУДНЯЮСЬ ОТВЕТИТЬ','НЕТ ОТВЕТА') == False]
#
# TypeError: isin() takes 2 positional arguments but 3 were given

# %%
df2
# Out:
# 0       10000.0
# 1       15000.0
# 2        5000.0
# 3        6000.0
# 4       12000.0
#          ...
# 4826    30000.0
# 4827     6000.0
# 4828    20000.0
# 4829     5300.0
# 4830    15000.0
# Name: ye4, Length: 4581, dtype: category
# Categories (166, object): [0.0, 300.0, 500.0, 700.0, ..., 85000.0, 'ЗАТРУДНЯЮСЬ ОТВЕТИТЬ', 'НЕТ ОТВЕТА', 'ОТКАЗ ОТ ОТВЕТА']

# %%
'НЕТ ОТВЕТА' in df1
# Out:
# False

# %%
df1.index
# Out:
# RangeIndex(start=0, stop=4831, step=1)

# %%
df2
# Out:
# 0       10000.0
# 1       15000.0
# 2        5000.0
# 3        6000.0
# 4       12000.0
#          ...
# 4826    30000.0
# 4827     6000.0
# 4828    20000.0
# 4829     5300.0
# 4830    15000.0
# Name: ye4, Length: 4529, dtype: category
# Categories (166, object): [0.0, 300.0, 500.0, 700.0, ..., 85000.0, 'ЗАТРУДНЯЮСЬ ОТВЕТИТЬ', 'НЕТ ОТВЕТА', 'ОТКАЗ ОТ ОТВЕТА']

# %% [markdown]
# 99999997 ЗАТРУДНЯЮСЬ ОТВЕТИТЬ
# 99999998 ОТКАЗ ОТ ОТВЕТА
# 99999999 НЕТ ОТВЕТА

# %% [markdown]
# Смотрю, чтобы не было NaN в данных по размеру домохозяйства

# %%
for i in range(0,len(df.loc[:,"y_nfm"])):
    if df.loc[:,"y_nfm"][i] in range(0,14):
        continue
    else:
        print(df.loc[:,"y_nfm"][i])
# Out:
# 16.0
# 14.0

# %%
df.loc[:,"YREDID_H"]
# Out:
# 0       1017.0
# 1       1018.0
# 2       1020.0
# 3       1022.0
# 4       1023.0
#          ...
# 4826      69.0
# 4827     206.0
# 4828    6157.0
# 4829    3229.0
# 4830    3230.0
# Name: YREDID_H, Length: 4831, dtype: float64

# %% [markdown]
# Code-book RLMS-HSE
# ID_W Волна (год проведения исследования)
# 5 1994 год
# 29 2020 год
# ! 1997 год пропущен
# ----
# A3 НОМЕР СЕМЬИ
#
# A3.3 ХОТЯ БЫ ОДИН ЧЛЕН СЕМЬИ УЧАСТВОВАЛ В ИССЛЕДОВАНИИ

# %%
df_HH.head()
# Out:
#    YREDID_H    YID_H    XID_H    WID_H    VID_H    UID_H    TID_H    SID_H  \
# 0    1017.0  10003.0  10003.0  10003.0  10003.0  10003.0  10003.0  10003.0
# 1    1018.0  10004.0  10004.0      NaN  10004.0  10004.0  10004.0  10004.0
# 2    1020.0  10012.0  10012.0  10012.0  10012.0  10012.0  10012.0  10012.0
# 3    1022.0  10014.0  10014.0  10014.0  10014.0  10014.0  10014.0  10014.0
# 4    1023.0  10016.0  10016.0  10016.0  10016.0  10016.0  10016.0  10016.0
#
#      RID_H    QID_H  ...  yf14.12  yf14.13  yf14.14  yf14.15      yf14  \
# 0  10003.0  10003.0  ...      Нет      NaN      Нет      NaN   17376.0
# 1  10004.0  10004.0  ...      Нет      NaN      Нет      NaN   37500.0
# 2  10012.0  10012.0  ...      Нет      NaN      Нет      NaN   19700.0
# 3  10014.0  10014.0  ...      Нет      NaN      Нет      NaN   15985.0
# 4  10016.0  10016.0  ...      Нет      NaN      Нет      NaN  126000.0
#
#           yf16.1         yf16.2         yf16.3        yf16.4         yf16.5
# ...

# %%
df3=df_HH["yf14"][(df_HH["yf14"]!= 'ЗАТРУДНЯЮСЬ ОТВЕТИТЬ') & (df_HH["yf14"]!= 'НЕТ ОТВЕТА')& (df_HH["yf14"]!= 'ОТКАЗ ОТ ОТВЕТА')]
df3
# Out:
# 0        17376.0
# 1        37500.0
# 2        19700.0
# 3        15985.0
# 4       126000.0
#           ...
# 4826     81800.0
# 4827     11660.0
# 4828     56000.0
# 4829     19863.0
# 4830     33000.0
# Name: yf14, Length: 4641, dtype: category
# Categories (1829, object): [0.0, 700.0, 2300.0, 3000.0, ..., 1943500.0, 'ЗАТРУДНЯЮСЬ ОТВЕТИТЬ', 'НЕТ ОТВЕТА', 'ОТКАЗ ОТ ОТВЕТА']

# %%
df3=pd.to_numeric(df3)
df3.describe()
# Out:
# count    4.641000e+03
# mean     5.419312e+04
# std      5.092920e+04
# min      0.000000e+00
# 25%      2.555500e+04
# 50%      4.290000e+04
# 75%      6.900000e+04
# max      1.943500e+06
# Name: yf14, dtype: float64

# %%
1.943500e+06
# Out:
# 1943500.0

# %%
5.419312e+04
# Out:
# 54193.12

# %%
ax = df3.plot.kde()

# %%
df4=df3/df_HH["y_nfm"]
df4
# Out:
# 0       17376.0
# 1       18750.0
# 2       19700.0
# 3       15985.0
# 4       31500.0
#          ...
# 4826    16360.0
# 4827     5830.0
# 4828    28000.0
# 4829    19863.0
# 4830    33000.0
# Length: 4831, dtype: float64

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(range(len(df_HH["y_nfm"])),df_HH["y_nfm"])

# %% [markdown]
# ## Новое

# %%
for col in df_HH.columns:
    print(col)
# Out:
# YREDID_H
# YID_H
# XID_H
# WID_H
# VID_H
# UID_H
# TID_H
# SID_H
# RID_H
# QID_H
# PID_H
# OID_H
# NID_H
# MID_H
# LID_H
# KID_H
# JID_H
# IID_H
# HID_H
# GID_H
# FID_H
# EID_H
# DID_H
# CID_H
# BID_H
# AID_H
# y_origsm
# y_hhwgt
# region
# psu
# status
# popul
# site
# ya3
# ya3.3
# Y_ROUND
# YA4.1
# YA4.2
# YA5.1
# YA5.2
# YA8
# YB1.O
# YB1.N
# y_nfm
# YB1.1
# yidind1
# YB1.2.1
# YB1.2.23
# YB1.3
# YB1.4
# YB1.5
# YB2.1
# yidind2
# YB2.2.1
# YB2.2.23
# YB2.3
# YB2.4
# YB2.5
# YB2.9.1
# YB3.1
# yidind3
# YB3.2.1
# YB3.2.23
# YB3.3
# YB3.4
# YB3.5
# YB3.9.1
# YB3.9.2
# YB4.1
# yidind4
# YB4.2.1
# YB4.2.23
# YB4.3
# YB4.4
# YB4.5
# YB4.9.1
# YB4.9.2
# YB4.9.3
# YB5.1
# yidind5
# YB5.2.1
# YB5.2.23
# YB5.3
# YB5.4
# YB5.5
# YB5.9.1
# YB5.9.2
# YB5.9.3
# YB5.9.4
# YB6.1
# yidind6
# YB6.2.1
# YB6.2.23
# YB6.3
# YB6.4
# YB6.5
# YB6.9.1
# YB6.9.2
# YB6.9.3
# YB6.9.4
# YB6.9.5
# YB7.1
# yidind7
# YB7.2.1
# YB7.2.23
# YB7.3
# YB7.4
# YB7.5
# YB7.9.1
# YB7.9.2
# YB7.9.3
# YB7.9.4
# YB7.9.5
# ...

# %%
"ye9.1b","ye9.2b","ye9.3b","ye9.4b","ye9.4.1b","ye9.5b","ye9.6b","ye9.8b","ye9.9b","ye9.11b","ye9.10b","ye9.7b"

# %%
Нам нужно создать датафрейм, в котором будет id домохозяйства, доход и число членов

# %%
YID_H
y_nfm
yf14
ye4
ye6.1
ye6.2
ZE7.1.0B

ye7.3b
ye7.4b
# Out:
#   Input In [67]
#     ye6.1
#        ^
# SyntaxError: invalid syntax

# %%
df_hh_filtered=df_HH[['YID_H',"y_nfm","yf14","ye4",
       'ye6.1','ye6.2',
       'ye7.1.0b',"ye7.1.1b","ye7.2b","ye7.3b",'ye7.4b','ye7.5b',"ye7.6b","ye7.7b",'ye7.8b',"ye7.9b","ye7.10b",
       "ye8.1b",'ye8.2b','ye8.3b',   # топливо
       "ye9.1b","ye9.2b","ye9.3b","ye9.4b","ye9.4.1b","ye9.5b","ye9.6b","ye9.8b","ye9.9b","ye9.11b","ye9.10b","ye9.7b",#услуги
       "ye10", #аренда+жкх
       "ye11", #жкх
                      
      ]] 



df_hh_filtered
# Out:
#            YID_H  y_nfm      yf14      ye4    ye6.1  \
# 0        10003.0    1.0   17376.0  10000.0   5600.0
# 1        10004.0    2.0   37500.0  15000.0   2400.0
# 2        10012.0    1.0   19700.0   5000.0      NaN
# 3        10014.0    1.0   15985.0   6000.0      NaN
# 4        10016.0    4.0  126000.0  12000.0  15000.0
# ...          ...    ...       ...      ...      ...
# 4826  14290014.0    5.0   81800.0  30000.0  10000.0
# 4827  14290015.0    2.0   11660.0   6000.0      NaN
# 4828  14290016.0    2.0   56000.0  20000.0      NaN
# 4829  14290017.0    1.0   19863.0   5300.0   1300.0
# 4830  14290018.0    1.0   33000.0  15000.0   2500.0
#
#                           ye6.2 ye7.1.0b ye7.1.1b ye7.2b  ye7.3b  ...  \
# 0     В ДОМОХОЗЯЙСТВЕ НЕТ ДЕТЕЙ      NaN      NaN    NaN     NaN  ...
# 1     В ДОМОХОЗЯЙСТВЕ НЕТ ДЕТЕЙ      NaN   3000.0    NaN     NaN  ...
# 2                           NaN      NaN      NaN    NaN     NaN  ...
# ...

# %%
E3 Вспомните, сколько примерно денег все члены Вашей семьи
израсходовали на питание вне дома в течение последних 7
дней?

E4 Вспомните, сколько примерно денег все члены Вашей семьи
израсходовали на питание дома и вне дома в течение
последних 30 дней?

# %%
E6 Сколько Вы и дpугие члены домохозяйства заплатили за
одежду или обувь для членов домохозяйства в течение
дней? (СБЕРЕЖЕНИЯ)

E19.1B Сколько составила помощь Вашей семьи деньгами или
товарами в течение последних 30 дней родителям Вашим или
супруга? (в рублях)

E19.2B Сколько составила помощь Вашей семьи деньгами или
товарами в течение последних 30 дней детям Вашим или
супруга(и)? (в рублях)

E19.3B Сколько составила помощь Вашей семьи деньгами или
товарами в течение последних 30 дней бабушкам и дедушкам
Вашим или супруга(и)?

E19.4B Сколько составила помощь Вашей семьи деньгами или
товарами в течение последних 30 дней другим людям? (в
рублях)

E19.5B Сколько составила помощь Вашей семьи деньгами или
товарами в течение последних 30 дней другим людям? (в
рублях)

E20.2D В течение последних 30 дней сколько составляла в рублях
помощь детям Вашим или супруга(и), не являющимся членами
Вашего домохозяйства?

E20.4D В течение последних 30 дней сколько составляла в рублях
помощь внукам Вашим или супруга(и), не являющимся членами
Вашего домохозяйства?

# %%
plt.plot(range(len(df_HH["y_nfm"])),df_HH["y_nfm"])

# %%
df_HH.loc[:,"y_nfm"]
# Out:
# 0       1.0
# 1       2.0
# 2       1.0
# 3       1.0
# 4       4.0
#        ...
# 4826    5.0
# 4827    2.0
# 4828    2.0
# 4829    1.0
# 4830    1.0
# Name: y_nfm, Length: 4831, dtype: float64

# %% [markdown]
# # Лишнее

# %%
D8 - СБОР УРОЖАЯ

A За последние 12 месяцев Ваша семья собрала урожай 

B Сколько всего килограмм собрали?

C Сколько килограмм потребили в семье в натуральном или
переработанном виде?

D Сколько килограмм отдали бесплатно родственникам и другим
людям в натуральном или переработанном виде? 

E Сколько килограмм продали в натуральном или
переработанном виде?

D8.1 - КАРТОФЕЛЬ
D8.2 - ПОМИДОРЫ
D8.3 - ОГУРЦЫ
D8.4 - СВЕКЛА
D8.5 - МОРКОВЬ
D8.6 - КАПУСТА
D8.7 - лука, чеснока
D8.8 - кабачков, патиссонов, тыкв
D8.9 - урожай другиховощей
D8.10 - БАХЧЕВЫЕ
D8.11 - ЗЕРНОВЫЕ
D8.12 - БОБОВЫЕ
D8.13 - КУКУРУЗВ
D8.14 - ТАБАК
D8.15 - Клубники, малины
D8.16 - смородины, крыжовника
D8.17 - облепихи
D8.18 - других ягод
D8.19 - Яблок
D8.20 - груш
D8.21 - слив вишни, черешни
D8.22 - абрикосов, персиков
D8.23 - винограда
D8.24 - других фруктов
D8.25 - орехов
D8.26 - урожай цветов
D8.27
D8.28
D8.29
D8.30

# %%
D9 Вы продавали в течение последних 30 дней что-либо из
выращенного на Вашей земле в течение последних 12
месяцев?

D10 Сколько денег Ваша семья выручила в течение последних 30
дней от продажи выращенного на Вашей земле в течение
последних 12 месяцев?

D11 Держала ли Ваша семья в течение последних 12 месяцев
какой-нибудь скот, птицу, пчел?

D12 Вы продавали в течение последних 30 дней какой-нибудь
скот, птицу, пчел в живом виде?

D13 Сколько денег Ваша семья выручила в течение последних 30
дней от продажи скота, птицы, пчел в живом виде?

D14 - ТОЖЕ САМОЕ ДЛЯ МЯСА

D15 В течение последних 30 дней Вы продавали что-либо из
продукции животноводства, птицеводства, пчеловодства, 
произведенной в Вашем хозяйстве за последние 12 месяцев?

F14.15 На какую сумму Ваша семья получила налоговый вычет за
последние 12 месяцев?

# %%
F14 Каким был денежный доход всей Вашей семьи в течение
последних 30 дней? Включите сюда все денежные поступления
всех членов семьи, в том числе и в валюте, но валюту переведите в рубли

F14.1 Если говорить о последних 12 месяцах, какую часть доходов
Вашей семье удалось отложить: дома или на банковских
вкладах, в рублях или в валюте. Сколько примерно это
будет в процентах от всего дохода семьи?

F14.3 Сколько всего денег должна Ваша семья? Если долги
исчисляются в долларах, то переведите эту сумму в рубли

F14.0 Сколько Вашей семье удалось накопить, то есть какие
сбережения есть у Вашей семьи на сегодняшний день - дома
или на банковских вкладах, в рублях или в валюте, или в
ценных бумагах? Оцените, сколько это будет в рублях.

F15 Как Вы считаете, Вы все знаете о доходах членов Вашей
семьи за последние 30 дней?

# %% [markdown]
# F20.1B Сколько всего в рублях в течение последних 12 месяцев Ваше домохозяйство истратило на на платежи за обучение в
# частной школе - на основе официального договора или
# другого финансового документа?
#
#
# F20.2B Сколько всего в рублях в течение последних 12 месяцев
# Ваше домохозяйство истратило на дополнительные занятия в
# государственной школе?
#
#
# F20.3B Сколько всего в рублях в течение последних 12 месяцев
# Ваше домохозяйство истратило на занятия с репетиторами в
# государственной или частной школе и(или) вне школы, кроме
# подготовки к поступлению в ВУЗы и техникумы?
#
# F20.4B Сколько всего в рублях в течение последних 12 месяцев
# Ваше домохозяйство истратило на взносы, сборы,
# пожертвования в помощь учебному заведению, например, на
# охрану, ремонт, покупку школьного оборудования?
#
#
# F20.5B Сколько всего в рублях в течение последних 12 месяцев
# Ваше домохозяйство истратило на подарки в виде товаров
# или денег учителям и другим работникам учебного
# заведения?
#
# F20.6B Сколько всего в рублях в течение последних 12 месяцев
# Ваше домохозяйство истратило на что-то еще, связанное с
# обучением членов домохозяйства в общеобразовательной
# школе?

# %%
F21 Учился ли кто-то из членов Вашего домохозяйства в ПТУ или
в среднем специальном учебном заведении - техникуме,
медицинском, музыкальном или другом училище, колледже - в
последние 12 месяцев?

F23.1B Сколько всего в рублях в течение последних 12 месяцев
Ваше д/х истратило на обучение в част. учебном заведении
или на платной основе в гос.учебном заведении на основе
официального договора или другого финансового документа?

F23.2B Сколько всего в рублях в течение последних 12 месяцев
Ваше домохозяйство истратило на оплату факультативных
предметов в государственном учебном заведении при
обучении на бесплатной основе?

F23.3B Сколько всего в рублях в течение последних 12 месяцев
Ваше домохозяйство истратило на занятия с репетиторами в
частном или государственном учебном заведении и(или) вне
его, кроме подготовки к поступлению в ВУЗы и техникумы?

F23.4B Сколько всего в рублях в течение последних 12 месяцев
Ваше домохозяйство истратило на оплату сдачи и пересдачи
экзаменов, зачетов, курсовых и дипломных работ?

F23.5B Сколько всего в рублях в течение последних 12 месяцев
Ваше домохозяйство истратило на взносы, сборы,
пожертвования в помощь учебному заведению, например, на
охрану, ремонт, покупку оборудования?

F23.6B Сколько всего в рублях в течение последних 12 месяцев
Ваше домохозяйство истратило на подарки в виде товаров
или денег преподавателям и другим работникам учебного
заведения?

F23.7B Сколько всего в рублях в течение последних 12 месяцев
Ваше домохозяйство истратило на оплату общежития или
снимаемого жилья?

F23.7B Сколько всего в рублях в течение последних 12 месяцев
Ваше домохозяйство истратило на оплату общежития или
снимаемого жилья?

# %%
F24 Учился ли кто-то из членов Вашего домохозяйства в высшем
учебном заведении - институте, университете, академии - в
последние 12 месяцев?

F26.1B Сколько всего в рублях в течение последних 12 месяцев
Ваше домохозяйство истратило на платежи за обучение в
частном ВУЗе или на платной основе в государственном ВУЗе
- на основе официального договора или другого финансового
документа?

F26.2B Сколько всего в рублях в течение последних 12 месяцев
Ваше домохозяйство истратило на оплату факультативных
предметов в государственном ВУЗе при обучении на
бесплатной основе?

F26.3B Сколько всего в рублях в течение последних 12 месяцев
Ваше домохозяйство истратило
3 СООБРАЗИТЕЛЕН, КАК БОЛЬШИНСТВО РЕСПОНДЕНТОВ
4 ЗНАЧИТЕЛЬНО СООБРАЗИТЕЛЬНЕЕ, ЧЕМ БОЛЬШИНСТВО РЕСПОНДЕНТОВ
99999999 НЕТ ОТВЕТА

G6 ОЦЕНИТЕ ИСКРЕННОСТЬ И ОТКРЫТОСТЬ РЕСПОНДЕНТА. РЕСПОНДЕНТ:
1 ОЧЕНЬ ЗАКРЫТЫЙ, НЕИСКРЕННИЙ
2 ИСКРЕНЕН И ОТКРЫТ ТАК ЖЕ, КАК БОЛЬШИНСТВО РЕСПОНДЕНТОВ
3 ЗНАЧИТЕЛЬНО БОЛЕЕ ИСКРЕНЕН И ОТКРЫТ, ЧЕМ БОЛЬШИНСТВО РЕСПОНДЕНТОВ
99999999 НЕТ ОТВЕТА

G7 ОТМЕТЬТЕ, НАСКОЛЬКО ПО-ВАШЕМУ МНЕНИЮ НАДЕЖНА ПОЛУЧАЕМАЯ
ИНФОРМАЦИЯ
1 НАДЕЖНАЯ
2 ЗАПИСАНО НЕДОСТАТОЧНО ИНФОРМАЦИИ
3 НЕНАДЕЖНАЯ
99999999 НЕТ ОТВЕТА

# %% [markdown]
# # Перевод аналогичного пакета R в Python

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
priceNames, shareNames, totExpName, data - обязательные аргументы функции

# %%
Сначала надо воспроизвести на конкретном примере, а потом обобщить пример до функции

# %%
import gzip

# %% [markdown]
# There are four mandatory arguments: **priceNames** must be a vector of strings that specifies
# the variable names of the prices, **shareNames** must be a vector of strings that specifies the
# variable names of the expenditure shares, **totExpName** must be a string that specifies the
# variable name of total expenditure, and data specifies a data frame that contains these
# variables. The most important optional arguments are **method** and **priceIndex**: method
# specifies the estimation method of the *AIDS* (e.g., "LA" for the *LA-AIDS*, equation 9) and
# priceIndex specifies the price index for the *LA-AIDS* (e.g., "S" for the Stone price index,
# equation 10).
#
#
# We will demonstrate the usage of aidsEst by analyzing U.S. food demand using annual
# consumption data that are published in Blanciforti, Green, and King (1986). The data set
# Blanciforti86 that is included in the R package micEconAids provides these data.
# We start this analysis by loading the micEconAids package and the data set Blanciforti86.

# %%
import pandas as pd

# %%
Blanciforti86 = pd.read_csv(r'C:\Users\79618\Desktop\Blanciforti86.txt', sep=" ")
Blanciforti86
# Out:
#        xAgg1  xAgg2   xAgg3   xAgg4  xAgg5   xAgg6   xAgg7   xAgg8  xAgg9  \
# 1947   40142  12364   22531   14065   5288   10714    6821   17251   7904
# 1948   42717  11909   24010   15851   6077   11858    7754   19735   8607
# 1949   41730  11804   23121   17684   5972   12442    7995   22079   8781
# 1950   42998  12141   23437   19657   6697   13242    8618   27405   9628
# 1951   48323  12770   25071   22049   7236   14377    9297   26349  10571
# 1952   50835  13655   26160   24522   7560   15519   10058   25412  10630
# 1953   51918  14005   26507   27310   7937   16689   11020   28874  11032
# 1954   53376  13809   26707   29698   8504   17083   11906   28297  11074
# 1955   55218  14163   27930   31719   9274   18329   12614   34705  11906
# 1956   57758  14773   29169   33965   9948   19734   13679   33688  12610
# 1957   61281  15352   29458   36410  10558   21163   15024   34871  13381
# 1958   63977  15732   29810   39000  11219   21983   16337   32213  13867
# ...

# %%
Blanciforti86=Blanciforti86[0:32] #берем строки с 1947 по 1978
Blanciforti86
# Out:
#        xAgg1  xAgg2   xAgg3   xAgg4  xAgg5   xAgg6   xAgg7   xAgg8  xAgg9  \
# 1947   40142  12364   22531   14065   5288   10714    6821   17251   7904
# 1948   42717  11909   24010   15851   6077   11858    7754   19735   8607
# 1949   41730  11804   23121   17684   5972   12442    7995   22079   8781
# 1950   42998  12141   23437   19657   6697   13242    8618   27405   9628
# 1951   48323  12770   25071   22049   7236   14377    9297   26349  10571
# 1952   50835  13655   26160   24522   7560   15519   10058   25412  10630
# 1953   51918  14005   26507   27310   7937   16689   11020   28874  11032
# 1954   53376  13809   26707   29698   8504   17083   11906   28297  11074
# 1955   55218  14163   27930   31719   9274   18329   12614   34705  11906
# 1956   57758  14773   29169   33965   9948   19734   13679   33688  12610
# 1957   61281  15352   29458   36410  10558   21163   15024   34871  13381
# 1958   63977  15732   29810   39000  11219   21983   16337   32213  13867
# ...

# %%
priceNames=["pFood1", "pFood2", "pFood3", "pFood4"]
shareNames=["wFood1", "wFood2", "wFood3", "wFood4"]

# %%
df5
# Out:
#    "xAgg1" "xAgg2" "xAgg3" "xAgg4" "xAgg5" "xAgg6" "xAgg7" "xAgg8" "xAgg9" "xAgg10" "xAgg11" "xAgg" "xcAgg1" "xcAgg2" "xcAgg3" "xcAgg4" "xcAgg5" "xcAgg6" "xcAgg7" "xcAgg8" "xcAgg9" "xcAgg10" "xcAgg11" "xcAgg" "pAgg1" "pAgg2" "pAgg3" "pAgg4" "pAgg5" "pAgg6" "pAgg7" "pAgg8" "pAgg9" "pAgg10" "pAgg11" "population3" "wAgg1" "wAgg2" "wAgg3" "wAgg4" "wAgg5" "wAgg6" "wAgg7" "wAgg8" "wAgg9" "wAgg10" "wAgg11" "xFoodUsdoc" "xFoodUsda" "xFoodNew" "pMeat1" "pMeat2" "pMeat3" "pMeat4" "cMeat1" "cMeat2" "cMeat3" "cMeat4" "xMeat1"  \
# 0   "1947" 40142 12364 22531 14065 5288 10714 6821...
# 1   "1948" 42717 11909 24010 15851 6077 11858 7754...
# 2   "1949" 41730 11804 23121 17684 5972 12442 7995...
# 3   "1950" 42998 12141 23437 19657 6697 13242 8618...
# 4   "1951" 48323 12770 25071 22049 7236 14377 9297...
# 5   "1952" 50835 13655 26160 24522 7560 15519 1005...
# 6   "1953" 51918 14005 26507 27310 7937 16689 1102...
# 7   "1954" 53376 13809 26707 29698 8504 17083 1190...
# ...

# %%
len(priceNames)
# Out:
# 4

# %%
• Stone price index (’S’), 
• Stone price index with lagged shares (’SL’)
• loglinear analogue to the Paasche price index (’P’)
• loglinear analogue of the Laspeyres price index (’L’) 
• simplified loglinear analogue of the Laspeyres price index (’Ls’) 
• Tornqvist price index (’T’).

# %%
aidsEst <- function( priceNames, shareNames, totExpName,
      data, method = "LA", priceIndex = "Ls", pxBase = 1,
      hom = TRUE, sym = TRUE,
      shifterNames = NULL, instNames = NULL,
      estMethod = ifelse( is.null( instNames ), "SUR", "3SLS" ),
      ILmaxiter = 50, ILtol = 1e-5, alpha0 = 0, restrict.regMat = FALSE, ... )
#===============================================================================
#Сначала сравниваем длины priceNames и shareNames

{

   if( length( priceNames ) != length( shareNames ) ) {
      stop( "arguments 'priceNames' and 'shareNames' must have the same length" )
   }
    
#===============================================================================
#???????????????????????????????????????????????????????????????????????????????
   nGoods <- length( priceNames )
   nShifter <- length( shifterNames )
   extractPx <- function( method ) {
      px <- substr( method, 4, nchar( method ) )
      return( px )
   }
    
#===============================================================================
#???????????????????????????????????????????????????????????????????????????????
   if( ! method %in% c( "LA", "IL", "MK" ) ) {
      if( nchar( method ) >= 4 && substr( method, 3, 3 ) == ":" &&
         substr( method, 1, 2 ) %in% c( "LA", "IL", "MK" ) ) {
            priceIndex <- extractPx( method )
            warning( "using price index specified in argument 'method',",
               " ignoring argument 'priceIndex'" )
         method <- substr( method, 1, 2 )
      } else {
         stop( "argument 'method' must be either",
            " 'LA' (for 'Linear Approximation') or",
            " 'IL' (for 'Iterated Linear Least Squares')" )
      }
   } 
    
#===============================================================================
#Проверка на допустимость типа индекста цен 
   if( !( priceIndex %in% c( "S", "SL", "P", "L", "Ls", "T" ) ) ) {
      stop( "argument 'priceIndex' that specifies the price index must be either",
         " 'S' (Stone index), 'SL' (Stone index with lagges shares),",
         " 'P' (Paasche index), 'L' (Laspeyres index),",
         " 'Ls' (Laspeyres index, simplified), or",
         " 'T' (Tornqvist index)" )
   }
    
    
#===============================================================================
#Проверка на то, что из симметрии следует гомогенность
   if( sym && !hom ) {
      hom <- TRUE  # symmetry implies homogeneity
      warning( "symmetry implies homogeneity: imposing additionally homogeniety" )
   }
    
#===============================================================================    
#проверка на NA в данных и исключение строк с NA
    
   allVarNames <- c( priceNames, shareNames, totExpName, instNames, shifterNames )
   if( sum( is.na( data[ , allVarNames ] ) ) > 0 ) {
      warning( "there are some NAs in the data,",
         " all observations (rows) with NAs are excluded from the analysis" )
      data <- data[ !is.na( rowSums( data[ , allVarNames ] ) ), ]
   }
    
#===============================================================================    
#подсчет числа наблюдений (строк)
   nObs   <- nrow( data )      # number of observations
    
#===============================================================================    
#Мы создаем сэмпл с числом наблюдений, и если SL, то выкидываем первое наблюдение
   sample <- if( priceIndex == "SL") c( 2:nObs ) else c( 1:nObs )
    
#===============================================================================    
#???????????????????????????????????????????????????????????????????????????????    
   result <- list()
   result$call <- match.call()
    
#===============================================================================    
#Подсчет средних долей и цен      
   wMeans <- numeric( nGoods )  # mean expenditure shares
   pMeans <- numeric( nGoods )  # mean prices
    
#===============================================================================    
#Находим среднюю по полным расходом
   xtMean <- mean( data[[ totExpName ]][ sample ] )
    
#===============================================================================    
#Для каждого блага считаются средние ??????(по благам)??????????????????????????
   for( i in seq( nGoods ) ) {
      wMeans[ i ] <- mean( data[[ shareNames[ i ] ]][ sample ] )
      pMeans[ i ] <- mean( data[[ priceNames[ i ] ]][ sample ] )
   }

#===============================================================================    
#nShifter=NULL, сдвиг ??????????????????????????????????????????????????????????
   if( nShifter > 0 ) {
      sMeans <- numeric( nShifter )
      for( i in seq( nShifter ) ) {
         sMeans[ i ] <- mean( data[[ shifterNames[ i ] ]][ sample ] )
      }
   }
    
    
#===============================================================================    
#===============================================================================
#===============================================================================
#===============================================================================
#===============================================================================
#Логарифмируем индекс цен!!!!!!!, но тут aidsPx. 
#Тут используется авторская функция, которая вычисляет лог индексы цен
#Надо написать сой аналог
#???????????????????????????????????????????????????????????????????????????????
    
   # log of price index
   lnp  <- aidsPx( priceIndex, priceNames, shareNames = shareNames, data = data,
      base = pxBase )
    
#===============================================================================
#Подготовка датафрейма
#???????????????????????????????????????????????????????????????????????????????  
   # prepare data.frame
   sysData <- data.frame( xt = data[[ totExpName ]],
      lxtr = ( log( data[[ totExpName ]] ) - lnp ) )
    
#===============================================================================
#Для каждого блага:
#paste - трансформирует в строки и соединяет с другими
#w1,w2,w3,w4...
#Логарифмированные цены:
#lp1,lp2,lp3,lp4...
   for( i in 1:nGoods ) {
      sysData[[ paste( "w", i, sep = "" ) ]] <- data[[ shareNames[ i ] ]]
      sysData[[ paste( "lp", i, sep = "" ) ]] <- log( data[[ priceNames[ i ] ]] )
   }
    
    
#===============================================================================
#дефолтный instNames = NULL - это инструментальные переменные
#если NULL, то ivFormula = NULL
#Иначе:
#метод оценки становится 3SLS,
#т.е. метод оценки трехстадийный метод оценки наименьших квадратов
#ivFormula = ~
#???????????????????????????????????????????????????????????????????????????????
    
   if( is.null( instNames )) {
      ivFormula <- NULL
   } else {
      estMethod <- "3SLS"
      ivFormula <- "~"
      for( i in 1:length( instNames ) ) {
         sysData[[ paste( "i", i, sep = "" ) ]] <- data[[ instNames[ i ] ]]
         ivFormula <- paste( ivFormula, " + i", as.character( i ), sep = "" )
      }
      ivFormula <- as.formula( ivFormula )
   }
    
    
#===============================================================================    
#дефолтный shifterNames=NULL
#???????????????????????????????????????????????????????????????????????????????    
   if( is.null( shifterNames )) {
      shifterFormula <- NULL
   } else {
      for( i in 1:length( shifterNames ) ) {
         sysData[[ paste( "s", i, sep = "" ) ]] <- data[[ shifterNames[ i ] ]]
      }
   }
    
    
#=============================================================================== 
#===============================================================================
#===============================================================================
#===============================================================================
#===============================================================================
#Авторская функция задающая условия симметричности и гомогенности
   restr <- .aidsRestr( nGoods = nGoods, hom = hom, sym = sym,
                       restrict.regMat = restrict.regMat, nShifter = nShifter )
    
      # restrictions for homogeneity and symmetry

#=============================================================================== 
#===============================================================================
#===============================================================================
#===============================================================================
#===============================================================================
#Авторская функция для системы уравнений LA-AIDS
   system <- .aidsSystem( nGoods = nGoods, nShifter = nShifter ) # LA-AIDS equation system
   # estimate system

#===============================================================================    
#systemfit - Linear Equation System Estimation    
   if( restrict.regMat ) {
      est <- systemfit( system, estMethod, data = sysData, restrict.regMat = restr,
         inst = ivFormula, ... )
   } else {
      est <- systemfit( system, estMethod, data = sysData, restrict.matrix = restr,
         inst = ivFormula, ... )
   }

#===============================================================================    
#===============================================================================  
#===============================================================================  
   if( method == "LA" ) {
      result$coef <- .aidsCoef( coef( est ), nGoods = nGoods, nShifter = nShifter,
         cov = vcov( est ), priceNames = priceNames, shareNames = shareNames,
         shifterNames = shifterNames, df = df.residual( est ) )   # coefficients
      result$wFitted <- aidsCalc( priceNames, totExpName, data = data,
         coef = result$coef, priceIndex = lnp )$shares   # estimated budget shares
      iter <- est$iter
   } 
    
#===============================================================================  
#===============================================================================  
#===============================================================================  
#===============================================================================  
#===============================================================================  
#Если выбран другой метод оценки
#???????????????????????????????????????????????????????????????????????????????
    
    else if( method %in% c( "MK", "IL" ) ) {
      b       <- coef( est )# coefficients
      bd      <- b          # difference of coefficients between
                            # this and previous step
      iter    <- est$iter   # iterations of each SUR estimation
      ILiter <- 1          # iterations of IL Loop
      while( ( ( t( bd ) %*% bd ) / ( t( b ) %*% b ) )^0.5 > ILtol &&
            ILiter < ILmaxiter ) {
         ILiter <- ILiter + 1      # iterations of IL Loop
         bl     <- b              # coefficients of previous step
         sysData$lxtr <- log( data[[ totExpName ]] ) -
            aidsPx( "TL", priceNames, shareNames = shareNames, data = data,
            coef = .aidsCoef( coef( est ), nGoods = nGoods, nShifter = nShifter,
               alpha0 = alpha0 ) )
            # real total expenditure using Translog price index
         if( restrict.regMat ) {
            est <- systemfit( system, estMethod, data = sysData, restrict.regMat = restr,
               inst = ivFormula, ... )    # estimate system
         } else {
            est <- systemfit( system, estMethod, data = sysData, restrict.matrix = restr,
               inst = ivFormula, ... )    # estimate system
         }
         iter <- c( iter, est$iter ) # iterations of each estimation
         weightNewCoef <- 1
         b    <- weightNewCoef * coef( est ) + ( 1 - weightNewCoef ) * b # coefficients
         bd   <- b - bl  # difference between coefficients from this
                         # and previous step
      }
        
        
        
        
#===============================================================================
#РЕАЛЬНЫЕ ДЕФЛИРОВАННЫЕ РАСХОДЫ=LOG(ПОЛНЫЕ РАСХОДЫ)-логарифмированные цены
        
      # calculating log of "real" (deflated) total expenditure
      sysData$lxtr <- log( data[[ totExpName ]] ) -
         aidsPx( "TL", priceNames, data = data,
         coef = .aidsCoef( coef( est ), nGoods = nGoods, nShifter = nShifter,
            alpha0 = alpha0 ) )
        
        
#===============================================================================
#Калькуляция матрицы G       
#???????????????????????????????????????????????????????????????????????????????      
        
      # calculating matrix G
      Gmat <- cbind( rep( 1, nObs ), sysData$lxtr )
      for( i in 1:( nGoods ) ) {
         Gmat <- cbind( Gmat, sysData[[ paste( "lp", i, sep = "" ) ]] )
      }
        
        
        
#===============================================================================
#Если стоит ненулевой сдвиг спроса, то дополняем матрицу G
#???????????????????????????????????????????????????????????????????????????????          
        
      if( nShifter > 0 ) {
         for( i in 1:nShifter ) {
            Gmat <- cbind( Gmat, sysData[[ paste( "s", i, sep = "" ) ]] )
         }
      }
        
        
        
        
#===============================================================================        
#???????????????????????????????????????????????????????????????????????????????  
#Тестирование матрицы G
        
      # testing matrix G
      if( FALSE ) {
         for( i in 1:( nGoods - 1 ) ) {
            print( fitted( est$eq[[ i ]] ) - Gmat %*%
               coef( est )[ ( ( i - 1 ) * ( nGoods + 2 ) + 1 ):( i * (nGoods + 2 ) ) ] )
         }
      }
        
        
#===============================================================================         
#Калькуляция Якобиана        
#???????????????????????????????????????????????????????????????????????????????        
        
      # calculating matrix J
      jacobian <- .aidsJacobian( coef( est ), priceNames, totExpName, data = data,
         shifterNames = shifterNames, alpha0 = alpha0 )
        
        
        
#===============================================================================
#Если гомогенна, то .....
#???????????????????????????????????????????????????????????????????????????????    
        
      if( hom ) {
         modRegMat <- .aidsRestr( nGoods = nGoods, nShifter = nShifter,
            hom = hom, sym = sym, restrict.regMat = TRUE )
      } else {
         modRegMat <- diag( ( nGoods - 1 ) * ( nGoods + 2 + nShifter ) )
      }
      # Jmat <- t( modRegMat ) %*% ( diag( nGoods - 1 ) %x% t( Gmat ) ) %*% jacobian
      # JmatInv <- modRegMat %*% solve( Jmat ) %*% t( modRegMat )
      # bcov <- JmatInv  %*% ( est$residCov %x% ( t( Gmat ) %*% Gmat ) ) %*%
      #    t( JmatInv )
        
        
        
#===============================================================================
#crossprod - векторное произведение =|a|x|b|cos(a,b)
#???????????????????????????????????????????????????????????????????????????????        
      Jmat <- crossprod( modRegMat, ( diag( nGoods - 1 ) %x% t( Gmat ) ) ) %*% jacobian

        
#===============================================================================
#???????????????????????????????????????????????????????????????????????????????
      JmatInv <- modRegMat %*% solve( Jmat, t( modRegMat ) )
        
#===============================================================================
#???????????????????????????????????????????????????????????????????????????????
      bcov <- JmatInv  %*% ( est$residCov %x% crossprod( Gmat ) ) %*%
         t( JmatInv )

#===============================================================================
#???????????????????????????????????????????????????????????????????????????????
      result$coef <- .aidsCoef( coef( est ), nGoods = nGoods, nShifter = nShifter,
         cov = bcov, priceNames = priceNames, shareNames = shareNames,
         shifterNames = shifterNames, df = df.residual( est ) )  # coefficients

#===============================================================================
#???????????????????????????????????????????????????????????????????????????????
      result$coef$alpha0 <- alpha0

#===============================================================================
#===============================================================================
#===============================================================================
#===============================================================================
#===============================================================================
#Вычисление доли и количества исходя из полученных коэффициентов
      result$wFitted <- aidsCalc( priceNames, totExpName, data = data,
         coef = result$coef, priceIndex = "TL" )$shares
        
         # estimated budget shares
      result$ILiter <- ILiter
   }

   names( result$wFitted ) <- paste( "wFitted", as.character( 1:nGoods ),
      sep = "" )
   result$wResid <- data.frame( matrix( NA, nrow = nObs, ncol = nGoods ) )
      # residuals of shares
   names( result$wResid ) <- paste( "wResid", as.character( 1:nGoods ), sep = "" )
   result$qObs <- data.frame( matrix( NA, nrow = nObs, ncol = nGoods ) )
      # observed quantities
   names( result$qObs ) <- paste( "qObs", as.character( 1:nGoods ), sep = "" )
   result$qFitted <- data.frame( matrix( NA, nrow = nObs, ncol = nGoods ) )
      # observed quantities
   names( result$qFitted ) <- paste( "qFitted", as.character( 1:nGoods ),
      sep = "" )
   result$qResid <- data.frame( matrix( NA, nrow = nObs, ncol = nGoods ) )
      # observed quantities
   names( result$qResid ) <- paste( "qResid", as.character( 1:nGoods ), sep = "" )
   for( i in 1:nGoods ) {
      result$wResid[ , i ] <- data[[ shareNames[ i ] ]] - result$wFitted[ , i ]
      result$qObs[ , i ]   <- data[[ shareNames[ i ] ]] * data[[ totExpName ]] /
         data[[ priceNames[ i ] ]]
      result$qFitted[ , i ] <- result$wFitted[ i ] * data[[ totExpName ]] /
         data[[ priceNames[ i ] ]]
      result$qResid[ , i ] <- result$qObs[ , i ] - result$qFitted[ , i ]
   }
   result$r2 <- numeric( nGoods )
   for( i in 1:( nGoods - 1 ) ) {
      result$r2[ i ] <- summary( est$eq[[ i ]] )$r.squared
   }
   result$r2[ nGoods ] <- rSquared( data[ sample, shareNames[ nGoods ] ],
      result$wResid[ sample, nGoods ] )
   names( result$r2 ) <- shareNames
   result$r2q <- numeric( nGoods ) # R2 values for consumed quantities
   for( i in 1:nGoods ) {
      result$r2q[ i ] <- rSquared( result$qObs[ sample , i ],
         result$qResid[ sample, i ] )
   }
   names( result$r2q ) <- paste( "q_", shareNames, sep = "" )
   result$iter <- iter
   result$est <- est
   result$method <- method
   result$priceIndex <- priceIndex
   result$lnp <- lnp
   result$wMeans <- wMeans
   result$pMeans <- pMeans
   result$xtMean <- xtMean
   if( nShifter > 0 ) {
      result$sMeans <- sMeans
   }
   result$shareNames <- shareNames
   result$priceNames <- priceNames
   result$totExpName <- totExpName
   result$basePrices <- attributes( result$lnp )$basePrices
   result$baseShares <- attributes( result$lnp )$baseShares

   class( result ) <- "aidsEst"
   return( result )
}

# %%
### ** Examples

   # Using data published in Blanciforti, Green & King (1986)
   data( Blanciforti86 )
   # Data on food consumption are available only for the first 32 years
   Blanciforti86 <- Blanciforti86[ 1:32, ]

   ## Repeating the demand analysis of Blanciforti, Green & King (1986)
   ## Note: Blanciforti, Green & King (1986) use scaled data,
   ##       which leads to slightly different results
   estResult <- aidsEst( c( "pFood1", "pFood2", "pFood3", "pFood4" ),
      c( "wFood1", "wFood2", "wFood3", "wFood4" ), "xFood",
      data = Blanciforti86, priceIndex = "SL", maxiter = 100 )
   print( estResult )

# %% [markdown]
# **1. variables that are needed for this analysis are the prices of the four categories:**
#
# priceNames <- c("pFood1", "pFood2", "pFood3", "pFood4")
#
# **2. the expenditure shares of these categories:**
#
# shareNames <- c("wFood1", "wFood2", "wFood3", "wFood4")
#
# **3. total expenditure on food:**
#
# totExpName <- "xFood"

# %%
"LA" (LA-AIDS) by default.

# %%
def aidsEst(priceNames, shareNames, totExpName,data,method="LA"):
#=================================================================
#Сначала проверяем длины векторов цен и долей расходов
    if len(priceNames)!=len(shareNames):
        print("arguments 'priceNames' and 'shareNames' must have the same length")
        break
#=================================================================
#
    nGoods=len(priceNames)
    nShifter=len(shifterNames)
    extractPx=function(method):
        px=substr(method, 4, nchar(method))#
        return(px)

# %%
### ** Examples

   # Using data published in Blanciforti, Green & King (1986)
   data( Blanciforti86 )
   # Data on food consumption are available only for the first 32 years
   Blanciforti86 <- Blanciforti86[ 1:32, ]

   ## Repeating the demand analysis of Blanciforti, Green & King (1986)
   ## Note: Blanciforti, Green & King (1986) use scaled data,
   ##       which leads to slightly different results
   estResult <- aidsEst( c( "pFood1", "pFood2", "pFood3", "pFood4" ),
      c( "wFood1", "wFood2", "wFood3", "wFood4" ), "xFood",
      data = Blanciforti86, priceIndex = "SL", maxiter = 100 )
   print( estResult )
